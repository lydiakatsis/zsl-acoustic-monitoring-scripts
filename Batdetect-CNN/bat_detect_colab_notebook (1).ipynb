# %% [markdown]
# # BatDetect
# ## Species specific classifications of bats from acoustic data ##
#
#
# *GPU is automatically enabled within the script* \
# Classification time:
# * 17 seconds per minute audio with 4 CPUS and no GPU
# * 5 seconds with 4 CPUS and 1 GPU
# * 7 seconds with 8 CPUS and 1 GPU
# * 6 seconds with 8 CPUS and 2 GPU

# %% [markdown]
# ## Mount buckets ##

# %%
# !mountpoint -q /home/jupyter/gcs_outputs && echo "mounted" || mkdir -p gcs_outputs; gcsfuse --implicit-dirs --rename-dir-limit=100 --disable-http2 --max-conns-per-host=100 "acoustic-processing-outputs" "/home/jupyter/gcs_outputs"
# !mountpoint -q /home/jupyter/gcs_raw && echo "mounted" || mkdir -p gcs_raw; gcsfuse --implicit-dirs --rename-dir-limit=100 --disable-http2 --max-conns-per-host=100 "acoustic-data-raw" "/home/jupyter/gcs_raw"
# Out:
# 2022/11/25 10:00:01.762842 Start gcsfuse/0.41.8 (Go version go1.18.4) for app "" using mount point: /home/jupyter/gcs_outputs
# 2022/11/25 10:00:01.790384 Opening GCS connection...
# 2022/11/25 10:00:01.944621 Mounting file system "acoustic-processing-outputs"...
# 2022/11/25 10:00:01.968268 File system has been successfully mounted.
# 2022/11/25 10:00:02.100917 Start gcsfuse/0.41.8 (Go version go1.18.4) for app "" using mount point: /home/jupyter/gcs_raw
# 2022/11/25 10:00:02.113611 Opening GCS connection...
# 2022/11/25 10:00:02.219514 Mounting file system "acoustic-data-raw"...
# 2022/11/25 10:00:02.234823 File system has been successfully mounted.

# %%
![ -d "/home/jupyter/batdetect_v3-master" ] && echo "Scripts are downloaded" || !gcloud storage cp -r 'gs://data-processing-scripts/batdetect_v3-master/' .
# Out:
# Scripts are downloaded

# %%
import os
path = "/home/jupyter/batdetect_v3-master"
os.chdir(path)

# %%
# import the necessary libraries
import glob
import config
import matplotlib.pyplot as plt

import bat_detect.utils.detector_utils as du
import bat_detect.utils.audio_utils as au
import bat_detect.utils.plot_utils as viz
import time

# %%
# setup the arguments
args = {}

# %% [markdown]
# ## Set input and output dirs below ##

# %%
args['ann_dir'] = "/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/"
args['audio_dir'] = "/home/jupyter/gcs_raw/nr-acoustic-data/bat-config/"

# %%
# Leave these as is
args['detection_threshold'] = 0.3
args['time_expansion_factor'] = 1
args['model_url'] = config.MODEL_URL
args['model_path'] = os.path.join('models', os.path.basename(args['model_url']))

args['cnn_features'] = False
args['spec_features'] = False
args['quiet'] = True
args['save_preds_if_empty'] = False
args['spec_slices'] = False
args['chunk_size'] = 3
args['save_preds_if_empty'] = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# /tmp/ipykernel_2771/2491431262.py in <module>
#       2 args['detection_threshold'] = 0.3
#       3 args['time_expansion_factor'] = 1
# ----> 4 args['model_url'] = config.MODEL_URL
#       5 args['model_path'] = os.path.join('models', os.path.basename(args['model_url']))
#       6
#
# NameError: name 'config' is not defined

# %%
# load the model
model, params = du.load_model(args['model_url'], args['model_path'])

# load files
files = du.get_audio_files(args['audio_dir'] )
error_files = []


# check if results file already exists - skip
for ii, audio_file in enumerate(files):
    msd = os.path.basename(os.path.dirname(audio_file))
    project = os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(audio_file))))
    results_file = os.path.join(args['ann_dir'], project, msd, str(os.path.basename(audio_file) + '.json'))
    
    if os.path.isfile(results_file):
        print(results_file)
        print("File exists")

        
    else:
        t1 = int(time.time())
        try:
            results = du.process_file(audio_file, model, params, args)
            if args['save_preds_if_empty'] or (len(results['pred_dict']['annotation']) > 0):
                msd = os.path.basename(os.path.dirname(audio_file))
                project = os.path.basename(os.path.dirname(os.path.dirname(os.path.dirname(audio_file))))
                results_path = os.path.join(args['ann_dir'], project, msd, os.path.basename(audio_file))
                print("Saving results to_" + results_path)
                du.save_results_to_file(results, results_path)
        except:
            error_files.append(audio_file)
            print("Error processing file!")
            
        t2 = int(time.time())
        print('File processed in ' + str(t2 - t1) + ' seconds')
    

# Shutdown the notebook   
# !sudo shutdown -h now
# Out:
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_210900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_211900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_212900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_213900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_214900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_215900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_220900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_221900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_222900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_223900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_224900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220325_225900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_210900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_211900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_212900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_213900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_214900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_215900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_220900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_221900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_222900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_223900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_224900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220326_225900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_210900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_211900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_212900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_213900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_214900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_215900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_220900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_221900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_222900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_223900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_224900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220327_225900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_210900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_211900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_212900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213500.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213600.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213700.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213800.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_213900.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_214000.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_214100.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_214200.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_214300.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_214400.WAV.json
# File exists
# /home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/M13_96_bat/20220328_214500.WAV.json
# File exists
# ...
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212400.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212800.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_212900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213000.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213400.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213800.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_213900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214100.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214400.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214700.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214800.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_214900.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215400.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215500.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215800.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_215900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220000.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220400.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220700.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220800.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_220900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221300.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221400.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221500.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221600.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221800.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_221900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222000.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222400.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222800.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_222900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_223000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_223100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_223200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_223300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220307_223400.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_212900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213100.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213400.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213800.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_213900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214400.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214800.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_214900.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215100.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215400.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215700.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215800.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_215900.WAV
# File processed in 6 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220000.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220100.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220200.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220300.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220400.WAV
# File processed in 4 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220500.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220600.WAV
# File processed in 5 seconds
# Saving results to_/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/nr-acoustic-data/MSD-43/20220308_220700.WAV
# File processed in 5 seconds

# %%
# print summary info for the individual detections 
print('Results for ' + results['pred_dict']['id'])
print('{} calls detected\n'.format(len(results['pred_dict']['annotation'])))

print('time\tprob\tlfreq\tspecies_name')
for ann in results['pred_dict']['annotation']:
    print('{}\t{}\t{}\t{}'.format(ann['start_time'], ann['class_prob'], ann['low_freq'], ann['class']))
# Out:
# Results for 20220310_214100.WAV
# 33 calls detected
#
# time	prob	lfreq	species_name
# 0.9175	0.227	24609	Plecotus austriacus
# 0.9825	0.286	23750	Plecotus austriacus
# 1.2445	0.281	24609	Plecotus austriacus
# 1.3115	0.195	26328	Plecotus austriacus
# 2.4235	0.211	24609	Plecotus austriacus
# 7.1445	0.233	24609	Plecotus austriacus
# 7.7325	0.259	25468	Plecotus austriacus
# 7.9305	0.277	23750	Plecotus austriacus
# 9.7645	0.316	58125	Pipistrellus pygmaeus
# 10.2235	0.33	58984	Pipistrellus pygmaeus
# 10.5515	0.24	23750	Plecotus austriacus
# 11.1415	0.305	24609	Plecotus austriacus
# 12.3205	0.302	58984	Pipistrellus pygmaeus
# 14.4165	0.295	58984	Pipistrellus pygmaeus
# 19.5955	0.31	58125	Pipistrellus pygmaeus
# 19.6605	0.369	58125	Pipistrellus pygmaeus
# 22.3485	0.353	58984	Pipistrellus pygmaeus
# 23.1995	0.271	23750	Plecotus austriacus
# 26.0165	0.218	25468	Plecotus austriacus
# 26.2135	0.314	24609	Plecotus austriacus
# 26.4765	0.24	25468	Plecotus austriacus
# 38.1415	0.27	26328	Plecotus austriacus
# 38.2075	0.308	24609	Plecotus austriacus
# 42.0075	0.367	58125	Pipistrellus pygmaeus
# 42.7955	0.234	24609	Plecotus austriacus
# 45.7445	0.235	24609	Plecotus austriacus
# 47.0545	0.309	58125	Pipistrellus pygmaeus
# 48.4295	0.235	28906	Plecotus austriacus
# 49.0205	0.208	29765	Plecotus austriacus
# 49.8735	0.32	23750	Plecotus austriacus
# 50.3325	0.244	26328	Plecotus austriacus
# 50.5285	0.322	24609	Plecotus austriacus
# 51.3805	0.264	24609	Plecotus austriacus

# %% [markdown]
# ## Concatenate results into one csv ##

# %%
import glob as glob
import pandas as pd
import os
from datetime import date

# %%
args['ann_dir']
# Out:
# '/home/jupyter/gcs_outputs/nr-acoustic-data/batdetect/'

# %%
d = date.today()
d = str(d)
results_list = glob.glob(args['ann_dir'] +  '*/*/*.csv')
metadata = pd.read_csv('/home/jupyter/gcs_raw/nr-acoustic-data/metadata/NR_deployment_2022_ARUs.csv')

li = []

for filename in results_list:
    df = pd.read_csv(filename)
    df['file_name'] = os.path.splitext(os.path.basename(filename))[0]
    df['path'] = filename
    df['date'] = [f[0:7] for f in df['file_name']]
    df['ID'] = os.path.basename(os.path.dirname(filename))
    li.append(df)

frame = pd.concat(li, axis=0, ignore_index=True)
frame = pd.merge(frame, metadata, on='ID', how='inner')
frame.to_csv(args['ann_dir'] + d + '_concatenated_results_bat_detect.csv')

# %%
frame
# Out:
#         id  det_prob  start_time  end_time  high_freq  low_freq  \
# 0        0     0.508      0.0935    0.1012      62871     47812
# 1        1     0.479      0.1865    0.1976      63606     47812
# 2        2     0.503      0.2855    0.2950      62486     47812
# 3        3     0.471      0.3735    0.3838      62890     47812
# 4        4     0.459      0.4695    0.4810      63016     46953
# ...     ..       ...         ...       ...        ...       ...
# 523334   0     0.319     17.7185   17.7283      31475     25468
# 523335   0     0.327     30.5635   30.5729      32066     25468
# 523336   0     0.362      6.1845    6.1967      30192     26328
# 523337   0     0.345     20.8655   20.8765      31065     26328
# 523338   0     0.373     26.0435   26.0551      29546     24609
#
#                             class  class_prob            file_name  \
# 0       Pipistrellus pipistrellus       0.477  20220325_210000.WAV
# 1       Pipistrellus pipistrellus       0.445  20220325_210000.WAV
# 2       Pipistrellus pipistrellus       0.477  20220325_210000.WAV
# 3       Pipistrellus pipistrellus       0.443  20220325_210000.WAV
# 4       Pipistrellus pipistrellus       0.406  20220325_210000.WAV
# ...                           ...         ...                  ...
# 523334        Eptesicus serotinus       0.168  20220311_221000.WAV
# 523335        Eptesicus serotinus       0.187  20220311_221300.WAV
# 523336          Nyctalus leisleri       0.245  20220311_221400.WAV
# 523337          Nyctalus leisleri       0.204  20220311_221500.WAV
# 523338          Nyctalus leisleri       0.218  20220311_221700.WAV
#
#                                                      path  ... SD card  \
# 0       /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...    M-13
# 1       /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...    M-13
# 2       /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...    M-13
# 3       /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...    M-13
# 4       /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...    M-13
# ...                                                   ...  ...     ...
# 523334  /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...  MSD-43
# 523335  /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...  MSD-43
# 523336  /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...  MSD-43
# 523337  /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...  MSD-43
# 523338  /home/jupyter/gcs_outputs/nr-acoustic-data/bat...  ...  MSD-43
#
#                       Config                         Housing  \
# 0          bat_50_sec.config  AudioMoth case w Schlegel vent
# 1          bat_50_sec.config  AudioMoth case w Schlegel vent
# 2          bat_50_sec.config  AudioMoth case w Schlegel vent
# 3          bat_50_sec.config  AudioMoth case w Schlegel vent
# 4          bat_50_sec.config  AudioMoth case w Schlegel vent
# ...                      ...                             ...
# 523334  bat_2100_2300.config  AudioMoth case w Schlegel vent
# 523335  bat_2100_2300.config  AudioMoth case w Schlegel vent
# 523336  bat_2100_2300.config  AudioMoth case w Schlegel vent
# 523337  bat_2100_2300.config  AudioMoth case w Schlegel vent
# 523338  bat_2100_2300.config  AudioMoth case w Schlegel vent
#
#                              Site area LocationID         lat           long  \
# 0                               Barnes        NaN  51.46957198  -0.248539788
# 1                               Barnes        NaN  51.46957198  -0.248539788
# 2                               Barnes        NaN  51.46957198  -0.248539788
# 3                               Barnes        NaN  51.46957198  -0.248539788
# 4                               Barnes        NaN  51.46957198  -0.248539788
# ...                                ...        ...          ...           ...
# 523334  Devonshire Road Nature Reserve        NaN     51.44503      -0.04977
# 523335  Devonshire Road Nature Reserve        NaN     51.44503      -0.04977
# 523336  Devonshire Road Nature Reserve        NaN     51.44503      -0.04977
# 523337  Devonshire Road Nature Reserve        NaN     51.44503      -0.04977
# 523338  Devonshire Road Nature Reserve        NaN     51.44503      -0.04977
#
#        Date deployed Date collected Data saved
# 0         25/03/2022            NaN          y
# 1         25/03/2022            NaN          y
# 2         25/03/2022            NaN          y
# 3         25/03/2022            NaN          y
# 4         25/03/2022            NaN          y
# ...              ...            ...        ...
# 523334    03/02/2022     25/03/2022          y
# 523335    03/02/2022     25/03/2022          y
# 523336    03/02/2022     25/03/2022          y
# 523337    03/02/2022     25/03/2022          y
# 523338    03/02/2022     25/03/2022          y
#
# [523339 rows x 23 columns]
